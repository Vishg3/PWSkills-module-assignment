# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('dataset.csv')

# %%
df.head()
# Out:
#   GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0      M   65        1               1        1              2
# 1      F   55        1               2        2              1
# 2      F   78        2               2        1              1
# 3      M   60        2               1        1              1
# 4      F   80        1               1        2              1
#
#    CHRONIC_DISEASE  FATIGUE  ALLERGY  WHEEZING  ALCOHOL_CONSUMING  COUGHING  \
# 0                2        1        2         2                  2         2
# 1                1        2        2         2                  1         1
# 2                1        2        1         2                  1         1
# 3                2        1        2         1                  1         2
# 4                1        2        1         2                  1         1
#
#    SHORTNESS_OF_BREATH  SWALLOWING_DIFFICULTY  CHEST_PAIN LUNG_CANCER
# ...

# %%
df.columns
# Out:
# Index(['GENDER', 'AGE', 'SMOKING', 'YELLOW_FINGERS', 'ANXIETY',
#        'PEER_PRESSURE', 'CHRONIC_DISEASE', 'FATIGUE', 'ALLERGY', 'WHEEZING',
#        'ALCOHOL_CONSUMING', 'COUGHING', 'SHORTNESS_OF_BREATH',
#        'SWALLOWING_DIFFICULTY', 'CHEST_PAIN', 'LUNG_CANCER'],
#       dtype='object')

# %%
df.dtypes
# Out:
# GENDER                   object
# AGE                       int64
# SMOKING                   int64
# YELLOW_FINGERS            int64
# ANXIETY                   int64
# PEER_PRESSURE             int64
# CHRONIC_DISEASE           int64
# FATIGUE                   int64
# ALLERGY                   int64
# WHEEZING                  int64
# ALCOHOL_CONSUMING         int64
# COUGHING                  int64
# SHORTNESS_OF_BREATH       int64
# SWALLOWING_DIFFICULTY     int64
# CHEST_PAIN                int64
# LUNG_CANCER              object
# dtype: object

# %%
df.describe()
# Out:
#                AGE      SMOKING  YELLOW_FINGERS      ANXIETY  PEER_PRESSURE  \
# count  3000.000000  3000.000000     3000.000000  3000.000000    3000.000000
# mean     55.169000     1.491000        1.514000     1.494000       1.499000
# std      14.723746     0.500002        0.499887     0.500047       0.500082
# min      30.000000     1.000000        1.000000     1.000000       1.000000
# 25%      42.000000     1.000000        1.000000     1.000000       1.000000
# 50%      55.000000     1.000000        2.000000     1.000000       1.000000
# 75%      68.000000     2.000000        2.000000     2.000000       2.000000
# max      80.000000     2.000000        2.000000     2.000000       2.000000
#
#        CHRONIC_DISEASE      FATIGUE      ALLERGY     WHEEZING  \
# count      3000.000000  3000.000000  3000.000000  3000.000000
# mean          1.509667     1.489667     1.506667     1.497333
# std           0.499990     0.499977     0.500039     0.500076
# ...

# %%
sns.histplot(df['AGE'],kde=True)
# Out:
# <Axes: xlabel='AGE', ylabel='Count'>

# %%
#data collected contains roughly equal number of people in age group from age 30 to 80 years old 
#youngest person is 30 years old and oldest is 80 years old
#mean age is 55.17 years and standard deviation is 14.72 years

# %%
sns.countplot(df['GENDER'])
# Out:
# <Axes: xlabel='count', ylabel='GENDER'>

# %%
#data collected contains roughly equal number of males and females

# %%
df.columns
# Out:
# Index(['GENDER', 'AGE', 'SMOKING', 'YELLOW_FINGERS', 'ANXIETY',
#        'PEER_PRESSURE', 'CHRONIC_DISEASE', 'FATIGUE', 'ALLERGY', 'WHEEZING',
#        'ALCOHOL_CONSUMING', 'COUGHING', 'SHORTNESS_OF_BREATH',
#        'SWALLOWING_DIFFICULTY', 'CHEST_PAIN', 'LUNG_CANCER'],
#       dtype='object')

# %%
df.ALCOHOL_CONSUMING.unique()
# Out:
# array([2, 1])

# %%
df.sample(3)
# Out:
#      GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 1266      F   71        1               1        1              2
# 2689      M   71        2               1        2              2
# 482       F   75        2               1        1              1
#
#       CHRONIC_DISEASE  FATIGUE  ALLERGY  WHEEZING  ALCOHOL_CONSUMING  \
# 1266                1        2        1         2                  1
# 2689                2        2        2         2                  1
# 482                 2        2        2         1                  1
#
#       COUGHING  SHORTNESS_OF_BREATH  SWALLOWING_DIFFICULTY  CHEST_PAIN  \
# 1266         2                    1                      1           1
# 2689         1                    1                      2           2
# 482          1                    1                      2           1
#
#      LUNG_CANCER
# 1266          NO
# 2689          NO
# 482           NO

# %%
fig, axes = plt.subplots(nrows=4, ncols=4, figsize=(20, 20))
fig.suptitle('Distributions of Variables', fontsize=20)
columns = df.columns
for i, col in enumerate(columns):
    ax = axes[i // 4, i % 4]
    if df[col].dtype == 'object':
        sns.countplot(data=df, x=col, ax=ax, palette='viridis')
        ax.set_title(f'Distribution of {col}')
    else:
        sns.histplot(df[col], bins=10, kde=True, ax=ax, color='skyblue')
        ax.set_title(f'Distribution of {col}')   
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()
# Out:
# /tmp/ipykernel_691/1301610388.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=col, ax=ax, palette='viridis')
# /tmp/ipykernel_691/1301610388.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=col, ax=ax, palette='viridis')

# %%
#SMOKING, YELLOW_FINGERS, ANXIETY, PEER_PRESSURE, CHRONIC_DISEASE, FATIGUE, ALLERGY, WHEEZING, 
#ALCOHOL_CONSUMING, COUGHING, SHORTNESS_OF_BREATH, SWALLOWING_DIFFICULTY, CHEST_PAIN
#Approximately equal distribution between 1 and 2

# %%
df.LUNG_CANCER.value_counts()
# Out:
# LUNG_CANCER
# YES    1518
# NO     1482
# Name: count, dtype: int64

# %%
#lung cancer categories: 'YES' (1518 occurrences), 'NO' (1482 occurrences)
#roughly eaual numbers
